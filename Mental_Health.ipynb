# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
ds = pd.read_csv('/content/Student Mental health.csv')

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
ds
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
ds.head(4)
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
# ...

# %%
ds.tail(4)
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# 97                      Year 2        3.00 - 3.49             No
# 98                      Year 3        3.50 - 4.00            Yes
# 99                      year 4        3.50 - 4.00             No
# 100                     Year 2        3.00 - 3.49             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 97                      Yes                  Yes                        No
# 98                      Yes                   No                       Yes
# ...

# %%
ds.sample(4)
# Out:
#               Timestamp Choose your gender   Age What is your course?  \
# 0        8/7/2020 12:02             Female  18.0          Engineering
# 40       8/7/2020 14:57             Female  24.0                  BIT
# 81  13/07/2020 10:12:18             Female  24.0      Diploma Nursing
# 22       8/7/2020 13:13             Female  24.0                  BCS
#
#    Your current year of Study What is your CGPA? Marital status  \
# 0                      year 1        3.00 - 3.49             No
# 40                     Year 3        3.00 - 3.49             No
# 81                     year 2        3.50 - 4.00             No
# 22                     year 1        3.50 - 4.00             No
#
#    Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                      Yes                   No                       Yes
# 40                      No                  Yes                        No
# ...

# %%
ds.shape
# Out:
# (101, 11)

# %%
ds.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
ds.dtypes
# Out:
# Timestamp                                        object
# Choose your gender                               object
# Age                                             float64
# What is your course?                             object
# Your current year of Study                       object
# What is your CGPA?                               object
# Marital status                                   object
# Do you have Depression?                          object
# Do you have Anxiety?                             object
# Do you have Panic attack?                        object
# Did you seek any specialist for a treatment?     object
# dtype: object

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Timestamp                                     101 non-null    object
#  1   Choose your gender                            101 non-null    object
#  2   Age                                           100 non-null    float64
#  3   What is your course?                          101 non-null    object
#  4   Your current year of Study                    101 non-null    object
#  5   What is your CGPA?                            101 non-null    object
#  6   Marital status                                101 non-null    object
#  7   Do you have Depression?                       101 non-null    object
#  8   Do you have Anxiety?                          101 non-null    object
# ...

# %%
ds.describe()
# Out:
#              Age
# count  100.00000
# mean    20.53000
# std      2.49628
# min     18.00000
# 25%     18.00000
# 50%     19.00000
# 75%     23.00000
# max     24.00000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
ds['Age']
# Out:
# 0      18.0
# 1      21.0
# 2      19.0
# 3      22.0
# 4      23.0
#        ...
# 96     21.0
# 97     18.0
# 98     19.0
# 99     23.0
# 100    20.0
# Name: Age, Length: 101, dtype: float64

# %%
ds['What is your course?']
# Out:
# 0             Engineering
# 1       Islamic education
# 2                     BIT
# 3                    Laws
# 4            Mathemathics
#               ...
# 96                    BCS
# 97            Engineering
# 98               Nursing
# 99       Pendidikan Islam
# 100    Biomedical science
# Name: What is your course?, Length: 101, dtype: object

# %%
ds['What is your course?'][50:71]
# Out:
# 50                   ALA
# 51                   BCS
# 52    Biomedical science
# 53                   koe
# 54                   BCS
# 55                   BCS
# 56                Kirkhs
# 57                  BENL
# 58                   BCS
# 59                  Benl
# 60                    IT
# 61                   BCS
# 62                   CTS
# 63                 engin
# 64                Engine
# 65                 Econs
# 66                   KOE
# 67                  MHSC
# 68                Malcom
# 69                   Kop
# 70    Biomedical science
# Name: What is your course?, dtype: object

# %%
ds[['What is your course?' , 'Age']]
# Out:
#     What is your course?   Age
# 0            Engineering  18.0
# 1      Islamic education  21.0
# 2                    BIT  19.0
# 3                   Laws  22.0
# 4           Mathemathics  23.0
# ..                   ...   ...
# 96                   BCS  21.0
# 97           Engineering  18.0
# 98              Nursing   19.0
# 99      Pendidikan Islam  23.0
# 100   Biomedical science  20.0
#
# [101 rows x 2 columns]

# %%
ds['Your current year of Study'].value_counts()
# Out:
# Your current year of Study
# year 1    41
# Year 3    19
# Year 2    16
# year 2    10
# year 4     8
# year 3     5
# Year 1     2
# Name: count, dtype: int64

# %%
ds['Do you have Anxiety?'].value_counts()
# Out:
# Do you have Anxiety?
# No     67
# Yes    34
# Name: count, dtype: int64

# %%
ds['Marital status'].value_counts()
# Out:
# Marital status
# No     85
# Yes    16
# Name: count, dtype: int64

# %%
pd.crosstab(ds['Marital status'], ds['Do you have Depression?'], normalize='all') * 100
# Out:
# Do you have Depression?         No        Yes
# Marital status
# No                       65.346535  18.811881
# Yes                       0.000000  15.841584

# %%
ds["What is your CGPA?"].value_counts()
# Out:
# What is your CGPA?
# 3.50 - 4.00     47
# 3.00 - 3.49     43
# 2.50 - 2.99      4
# 0 - 1.99         4
# 2.00 - 2.49      2
# 3.50 - 4.00      1
# Name: count, dtype: int64

# %%
above_average_cgpa = ds[ds['What is your CGPA?'] == '3.50 - 4.00']

# %%
above_average_cgpa
# Out:
#               Timestamp Choose your gender   Age What is your course?  \
# 5        8/7/2020 12:31               Male  19.0          Engineering
# 7        8/7/2020 12:33             Female  18.0                  BCS
# 9        8/7/2020 12:39               Male  18.0                Irkhs
# 10       8/7/2020 12:39             Female  20.0           Psychology
# 11       8/7/2020 12:39             Female  24.0          Engineering
# 14       8/7/2020 12:43             Female  18.0                KENMS
# 15       8/7/2020 12:43               Male  24.0                  BCS
# 18       8/7/2020 13:05             Female  20.0                  BIT
# 19       8/7/2020 13:07             Female  18.0       Marine science
# 22       8/7/2020 13:13             Female  24.0                  BCS
# 24       8/7/2020 13:17             Female  23.0                  BCS
# 25       8/7/2020 13:29             Female  18.0      Banking Studies
# ...

# %%
above_average_cgpa['Do you have Depression?'].value_counts()
# Out:
# Do you have Depression?
# No     35
# Yes    12
# Name: count, dtype: int64

# %%
pd.crosstab(ds['Choose your gender'] , ds['Do you have Panic attack?'] , normalize='index') *100
# Out:
# Do you have Panic attack?         No        Yes
# Choose your gender
# Female                     66.666667  33.333333
# Male                       69.230769  30.769231

# %%
pd.crosstab(ds['Choose your gender'] , ds['Do you have Anxiety?'] , normalize='index') *100
# Out:
# Do you have Anxiety?         No        Yes
# Choose your gender
# Female                68.000000  32.000000
# Male                  61.538462  38.461538

# %%
pd.crosstab(ds['Choose your gender'] , ds['Do you have Depression?'] , normalize='index') *100
# Out:
# Do you have Depression?         No        Yes
# Choose your gender
# Female                   61.333333  38.666667
# Male                     76.923077  23.076923

# %%
ds['Choose your gender'].value_counts()
# Out:
# Choose your gender
# Female    75
# Male      26
# Name: count, dtype: int64
